# %%
#object oriented programming

# %%
-Abstraction
-Encapusulation
-Polymorphism
-Inheritance

# %%
student1 = {
    "name": "harsha vardhan",
    "marks": "75"
}
student2 = {
    "name": "nothing",
    "marks": "100"
}

# %%
Python object can have multiple attributes

- callable (e.g. function and classes)
- iterable (e.g. list, string, generator)
-contextable (e.g. files)

# %%
class Person:
  pass

p = Person()
print(p)
# Out:
# <__main__.Person object at 0x7f6e8aa757f0>

# %%
hex(id(p))
# Out:
# '0x7f6e8aa757f0'

# %%
a = 1
def square(a):
  print(a**2)

# %%
class Person:
  def say_hi(self):
    print("Hello Everyone : I am {self.name}")

p = Person()

p.say_hi() # method call
Person.say_hi(p) # function call
# Out:
# Hello Everyone : I am {self.name}
# Hello Everyone : I am {self.name}
