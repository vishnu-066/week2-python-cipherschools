# %%
# lambda expressions

# %%
lambda a, b: a + b
# Out:
# <function __main__.<lambda>(a, b)>

# %%
print("Hello World")
# Out:
# Hello World

# %%
show = print
show("something")
# Out:
# something

# %%
names = ["harsha", "sai", "teja"]
for name in names:
  print(name)
# Out:
# harsha
# sai
# teja

# %%
names = ["harsha", "sai", "teja"]
for name in enumerate(names):
  print(name)
# Out:
# (0, 'harsha')
# (1, 'sai')
# (2, 'teja')

# %%
int a[] = {1, 2, 3}

# %%
a = 5
b = 9
