# %%
#tuples
a = [1, 2, 3]
a[0] = 100
a[2] = 200
a
# Out:
# [100, 2, 200]

# %%
a = (1, 2, 3, 4)
type(a)
# Out:
# tuple

# %%
def func(*args):
  print(type(args))

# %%
def sum_diff(a, b):
  s = a+b
  d = a-b

  return (s, d)
c = sum_diff(10, 5)
type(c)
# Out:
# tuple

# %%
a = (1, 2, 3, 4)
list(a)
# Out:
# [1, 2, 3, 4]

# %%
from IPython.utils.text import list_strings
Storage:in CPython, tuples are stored in a single block of memory, 
so creating a new tuple involves at worst a single call to allocate memory

indexing:Tuples are faster than lists

safety: it makes your code safer if you "write-protect" data that does not
need to be changed

# %%
#dictionaries
'''
a = [1, 2, 3, 4, 5]
a[0]
'''

a = dict()
a["name"]
a[1]
a[(1, 2)]

# %%
a = {
    "name": "harsha"
}
a["name"] = "sai teja"

# %%
key = "marks"
if key in a:
  print(a[key])
else:
  print("key does not exist")
